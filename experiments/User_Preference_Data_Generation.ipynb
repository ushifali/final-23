# %% [markdown]
# <a href="https://colab.research.google.com/github/ushifali/final-23/blob/master/User_Preference_Data_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
# Load attraction data
data = pd.read_csv('/content/drive/MyDrive/Filtering_Data/content_filtered_data_attraction.csv')
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0           274         274
# 1           239         239
# 2           257         257
# 3           234         234
# 4           236         236
#
#                                              address       city  \
# 0  Murugeshpalya, Jeevan Bima Nagar, Bengaluru, K...  Bengaluru
# 1  XMM8+X48, 1st Cross Rd, Bhuvaneswari Nagar, C ...  Bengaluru
# 2  2-6, 9th Cross Rd, Kaggadasapura, Bengaluru, K...  Bengaluru
# 3  3D, No, 3, 5th Cross Rd, Michael Palaya, H Col...  Bengaluru
# 4  Police Station, Near HAL, HAL Old Airport Rd, ...  Bengaluru
#
#                                          description   latitude  longitude  \
# 0                                                NaN  12.961314  77.656118
# 1                                                NaN  12.984916  77.665327
# 2                                                NaN  12.985504  77.675954
# 3                                                NaN  12.981284  77.646522
# 4  Aerospace company's museum featuring photograp...  12.954655  77.680906
#
#   price      state                                        street  \
# 0   NaN  Karnataka                                           NaN
# 1   NaN  Karnataka                        XMM8+X48, 1st Cross Rd
# 2   NaN  Karnataka                             2-6, 9th Cross Rd
# 3   NaN  Karnataka                       3D, No, 3, 5th Cross Rd
# 4   NaN  Karnataka  Police Station, Near HAL, HAL Old Airport Rd
#
#                                       title  totalScore  \
# 0                          GlobalTravellors         5.0
# 1                              Shiva Statue         4.7
# 2                          Chinimika layout         5.0
# 3                    Freedom Wall Bangalore         4.7
# 4  HAL Heritage Centre and Aerospace Museum         4.4
#
#                                     categories  \
# 0                           Tourist attraction
# 1             Tourist attraction, Hindu temple
# 2                           Tourist attraction
# 3                           Tourist attraction
# 4  Tourist attraction, Heritage museum, Museum
#
#                                            image_url  Distance
# 0  https://lh5.googleusercontent.com/p/AF1QipOOxD...  0.012503
# 1  https://lh5.googleusercontent.com/p/AF1QipP5XR...  0.014535
# 2                                                NaN  0.018832
# 3  https://lh5.googleusercontent.com/p/AF1QipNt7G...  0.021202
# 4  https://lh5.googleusercontent.com/p/AF1QipNb68...  0.022581

# %%
categories = set(','.join(data['categories']).split(','))
categories.remove('Tourist attraction')

# %%
# Load hotel data
data = pd.read_csv('/content/drive/MyDrive/Filtering_Data/content_filtered_data_hotel.csv', encoding='utf-8')
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                   property_name  \
# 0         15930       15930                  Shilton Suites
# 1         12785       12785  Nandhana Comforts Marathahalli
# 2         17759       17759                 The Libra Hotel
# 3          1378        1378             Boulevard Residence
# 4         17599       17599             The Grand Continent
#
#                                              address  \
# 0  No:2, Ulsoor Road (Parallel to MG Road) , Ulso...
# 1  No 1, 1st Floor, Outer Ring Rd, Near to Relien...
# 2  11/1, Hosur Main Road, In-Between Christ Unive...
# 3  Thanisandra Main Road,ICICI Thanisandra Main road
# 4  44B, 1st Main Road, Opp. Mini Forest,3rd Phase...
#
#                        area       city  \
# 0  Ulsoor,Central Bangalore  Bangalore
# 1              Marathahalli  Bangalore
# 2               Koramangala  Bangalore
# 3                    Hebbal  Bangalore
# 4                  JP Nagar  Bangalore
#
#                                    hotel_description  \
# 0  |Situated in the Silicon Valley of India, Shil...
# 1  Nestled in the city of Bangalore, Hotel Nandha...
# 2  Around 4 km from Lal Bagh and 9 km from the ra...
# 3  Boulevard Residence is nestled in Bangalore po...
# 4  Situated at a 20 minute drive from Bangalore C...
#
#                                     hotel_facilities  hotel_star_rating  \
# 0  Airport/Rlwy Stn Transfer|Business Centre|Curr...                2.0
# 1  Doctor on Call|Laundry Service|Restaurant|Room...                2.0
# 2  Airport Transfer|Doctor on Call|Laundry Servic...                2.0
# 3  24 hour security|24 hours power back-up|Airpor...                2.0
# 4  Airport/Rlwy Stn Transfer|Coffee Shop|Conferen...                2.0
#
#                                           image_urls  ...  longitude  \
# 0  //imghtlak.mmtcdn.com/hotels/20110121180320201...  ...  77.617424
# 1  //imghtlak.mmtcdn.com/images/hotels/2014102017...  ...  77.713085
# 2  //imghtlak.mmtcdn.com/images/hotels/2015090711...  ...  77.609272
# 3  //imghtlak.mmtcdn.com/images/hotels/2011120617...  ...  77.624625
# 4  //imghtlak.mmtcdn.com/images/hotels/2007012519...  ...  77.599166
#
#                                              pageurl  property_type province  \
# 0  http://hotelz.makemytrip.com/makemytrip/site/h...          Hotel      NaN
# 1  https://hotelz.makemytrip.com/makemytrip/site/...          Hotel      NaN
# 2  https://hotelz.makemytrip.com/makemytrip/site/...          Hotel      NaN
# 3  http://hotelz.makemytrip.com/makemytrip/site/h...          Hotel      NaN
# 4  http://hotelz.makemytrip.com/makemytrip/site/h...          Hotel      NaN
#
#   room_count room_facilities                           room_type      state  \
# 0        NaN             NaN                        Deluxe Suite  Telangana
# 1        NaN             NaN                     Standard|Deluxe  Karnataka
# 2        NaN             NaN  Economy Ac|Executive Ac|Premium Ac  Karnataka
# 3        NaN             NaN                       Standard Room  Karnataka
# 4        NaN             NaN                         Deluxe King  Karnataka
#
#   rating  Distance
# 0    4.5  0.047548
# 1    4.5  0.053065
# 2    4.5  0.065624
# 3    4.5  0.095512
# 4    4.5  0.087935
#
# [5 rows x 22 columns]

# %%
facilities = set(','.join(data['hotel_facilities']).split('|'))
facilities
# Out:
# {'',
#  ' 24-hr Room Service ',
#  ' Air Conditioned ',
#  ' Air Conditioning ',
#  ' Air Conditioning,Business Services:Business Center',
#  ' Air conditioning ',
#  ' Attached Bathroom ',
#  ' Attached Bathroom,Travel:Parking',
#  ' Balcony ',
#  ' Bath Tub ',
#  ' Bathrobe ',
#  ' Bathrobes ',
#  ' Bathrobes,Airport Transfer',
#  ' Bathroom Toiletries ',
#  ' Bathtub ',
#  ' Broadband Internet ',
#  ' Cable T V,if applicable)',
#  ' Cable Tv,24 hour room service',
#  ' DVD Player ',
#  ' DVD Player on Request ',
#  ' Daily Newspaper ',
#  ' Desk ',
#  ' Direct dial phone ',
#  ' Direct-dial phone ',
#  ' Electronic Safe ',
#  ' Equipped Kitchenette ',
#  ' Fireplace ',
#  ' Full-length mirror ',
#  ' Geyser In Bathroom ',
#  ' Hair Dryer ',
#  ' Hot & Cold Running Water ',
#  ' Hot & Cold water ',
#  ' Hot & Cold water,24 hours power back-up',
#  ' Hot/cold Water ',
#  ' Hot/cold Water,Business centre',
#  ' In-room safe ',
#  ' Intercom ',
#  ' Intercom Facility ',
#  ' Iron/ironing board (on request) ',
#  ' Iron/ironing board (on request),Basics:Internet',
#  ' Ironing Board ',
#  ' LCD TV ',
#  ' Living Room ',
#  ' Microwave,Doctor on Call',
#  ' Mineral Water ',
#  ' Mini bar ',
#  ' Minibar ',
#  ' Newspaper ',
#  ' Piped/Channel Music ',
#  ' Room Heater ',
#  ' Room Service ',
#  ' Safe Deposit Locker ',
#  ' Safe Deposit Locker,Doctor on Call',
#  ' Safe Deposit Locker,Food &amp; Beverage:Restaurant',
#  ' Satellite TV ',
#  ' Satellite television ',
#  ' Shower Area ',
#  ' Slippers ',
#  ' Sofa Unit ',
#  ' Sofa bed ',
#  ' Study Table ',
#  ' Tea coffee maker ',
#  ' Telephone ',
#  ' Television ',
#  ' Voice mail ',
#  ' Wardrobe ',
#  ' WiFi Internet ',
#  ',24 hour security',
#  ',Airport Transfer',
#  ',Airport/Rlwy Stn Transfer',
#  ',Personal Services:Room Service,Basics:Internet',
#  '24 Hour Power Supply',
#  '24 Hour Room Service',
#  '24 hour room service',
#  '24 hour security',
#  '24 hours front desk',
#  '24 hours power back-up',
#  '24-Hour Front Desk',
#  '24-Hour Security',
#  '24-hr Hot & Cold Water',
#  '24-hr Room Service',
#  'Adjoining Rooms',
#  'Adventure activities',
#  'Air Conditioning',
#  'Air conditioning',
#  'Airport transfer (price advised by hotel)',
#  'Airport/Rlwy Stn Transfer',
#  'Attached Bathroom',
#  'Attached Bathroom,Travel:Parking',
#  'Audio Visual Equipment',
#  'Backup generator',
#  'Balcony / Sit Out',
#  'Balcony / Sit Out, Airport/Rlwy Stn Transfer',
#  'Banquet Facility',
#  'Bar',
#  'Barber/beauty salon',
#  'Basic Room Amenities:Wake-Up Call Service,24 Hour Check in-Icon',
#  'Basic Room Amenities:Wake-Up Call Service,24 hour room service',
#  'Basic Room Amenities:Wake-Up Call Service,Car rental',
#  'Basic Room Amenities:Wake-Up Call Service,Credit cards accepted',
#  'Basic Room Amenities:Wake-Up Call Service,Travel:Travel Desk',
#  'Basics:Air Conditioning',
#  'Basics:Doctor on Call,24 hour room service',
#  'Basics:Doctor on Call,Food &amp; Beverage:Restaurant',
#  'Basics:Doorman',
#  'Basics:Housekeeping,Personal Services:24 Hour Front Desk',
#  'Basics:Housekeeping,Travel:Parking',
#  'Basics:Internet',
#  'Basics:Non-Smoking Rooms',
#  'Basics:Pets Allowed',
#  'Bathroom Toiletries',
#  'Bathroom Toiletries ',
#  'Bicycles on Hire',
#  'Bird watching',
#  'Board Room',
#  'Body treatments',
#  'Breakfast in the Room',
#  'Bus Parking',
#  'Bushwalking',
#  'Business Centre',
#  'Business Services:Conference Hall,Basics:Internet',
#  'Business Services:Meeting Room,Basics:Internet',
#  'Business center',
#  'Business services',
#  'Butler Service',
#  'Cable T V',
#  'Cable Tv',
#  'Cable Tv,24 hours power back-up',
#  'Cable Tv,Basics:Air Conditioning',
#  'Cable Tv,Food &amp; Beverage:Bar',
#  'Car Rental Facility',
#  'Car parking (Payable to hotel,Banquet facilities',
#  'Car rental',
#  'Catering Service',
#  'Catering services',
#  "Children's Play Area",
#  'Coffee Shop',
#  'Complimentary Wi-Fi access',
#  'Concierge',
#  'Conference / Banquet Hall',
#  'Conference Facilities',
#  'Conference suite',
#  'Cook on call,Food &amp; Beverage:Bar',
#  'Credit cards accepted',
#  'Currency Exchange',
#  'DVD Player',
#  'Daily Newspaper',
#  'Data Port',
#  'Desk',
#  'Desk,Airport/Rlwy Stn Transfer',
#  'Dining Hall',
#  'Dinning Area',
#  'Direct dial phone',
#  'Discotheque',
#  'Doctor on Call',
#  'Doorman',
#  'Dry Cleaning',
#  'Dry Cleaning,Basics:Internet',
#  'Dry cleaning/laundry service',
#  'Elevator/lift',
#  'Emergency power generator',
#  'Equipped Kitchenette',
#  'Executive floor',
#  'Express Check-In',
#  'Express Check-Out',
#  'Express check-in',
#  'Extra Bed (On Request)',
#  'Extra Mattress (On Request)',
#  'Female Traveler Room',
#  'Fitness Center',
#  'Food &amp; Beverage:Barbeque',
#  'Food &amp; Beverage:Restaurant',
#  'Free Newspaper',
#  'Free Parking',
#  'Free Use Of Wifi In Lobby',
#  'Free Wi Fi*',
#  'Free Wi-Fi',
#  'Free Wi-Fi Icon',
#  'Free Wi-Fi Internet Access Included',
#  'Free WiFi Internet',
#  'Free breakfast',
#  'Front Desk',
#  'Front desk',
#  'Garden,Travel:Car Rental',
#  'Geyser In Bathroom',
#  'Geyser In Bathroom,Airport Transfer',
#  'Guide Service',
#  'Gym',
#  'Gymnasium',
#  'Gymnasium/Health Club',
#  'Hairdryers',
#  'Handicap Facilities',
#  'Health Club',
#  'Hot & Cold Running Water',
#  'Hot & Cold water',
#  'Hot & Cold water,Basics:Internet',
#  'Hot/cold Water',
#  'Hot/cold Water ',
#  'Hotel Amenities:24-Hour Security',
#  'Hotel Amenities:24-Hour Security,Airport Transfer',
#  'Hotel Amenities:ATM / Cash Machine',
#  'Hotel Amenities:Courtyard,Backup generator',
#  'Housekeeping',
#  'Ice machine',
#  'Indoor Games',
#  'Indoor Multi Cuisine Restaurant',
#  'Indoor Restaurant',
#  'Indoor Swimming Pool',
#  'Information desk',
#  'Intercom',
#  'Intercom Facility',
#  'Internet Facility',
#  'Internet Services',
#  'Internet access',
#  'Internet/Wi-Fi',
#  'Iron,Airport Transfer',
#  'Ironing Board',
#  'Jacuzzi',
#  'LCD / Projector',
#  'LCD TV',
#  'LCD television with multi channel cable',
#  'Large Screen Television',
#  'Laundry',
#  'Laundry Service',
#  'Laundry Service (At a charge)',
#  'Lift',
#  'Limousine Service',
#  'Live Entertainment',
#  'Living Room',
#  'Lounge',
#  'Massage Centre',
#  'Medical services',
#  'Mineral Water',
#  'Mini Refrigerator',
#  'Multilingual staff',
#  'Nature trails',
#  'Newspapers',
#  'No Category:Bay View',
#  'No Category:Body Treatments',
#  'No Category:Conference facilities',
#  'No Category:Free Newspaper',
#  'No Category:Front Desk',
#  'No Category:Front Desk,Basics:Internet',
#  'No Category:Front Desk,Travel:Parking',
#  'Non-Smoking Rooms',
#  'Outdoor Activities',
#  'Outdoor Parking',
#  'Outdoor Swimming Pool',
#  'Parking',
#  'Parking Facility',
#  'Personal Services:24 Hour Front Desk',
#  'Personal Services:Dry Cleaning',
#  'Personal Services:Laundry',
#  'Personal Services:Room Service',
#  'Personal Services:Room Service,Basics:Air Conditioning',
#  'Phone Service',
#  'Piped/Channel Music',
#  'Porter',
#  'Railway Station Transfer',
#  'Recreation',
#  'Recreation:Beauty Salon',
#  'Recreation:Bonfire Arrangement,Business Centre',
#  'Recreation:Indoor Games',
#  'Recreation:Indoor Games,Airport/Rlwy Stn Transfer',
#  'Recreation:Kids Pool',
#  'Refrigerator',
#  'Restaurant',
#  'Restaurant/Bar',
#  'Restaurants that deliver',
#  'Room Service',
#  'Room Service 24 Hrs',
#  'Room Service 7 Am To 9 Pm',
#  'Room service',
#  'Room service (24 hours)',
#  'Safety Deposit Box',
#  'Satellite Television',
#  'Satellite television',
#  'Sauna',
#  'Separate sitting area,Business Services:Business Center',
#  'Shopping arcade',
#  'Shower Area',
#  'Shuttle Service',
#  'Sightseeing',
#  'Sofa Unit',
#  'Souvenirs/Gift Shop',
#  'Spa',
#  'Steam Bath',
#  'Steam Room',
#  'Steam bath',
#  'Study Table',
#  'Swimming Pool',
#  'Taxi Service',
#  'Taxi Services',
#  'Tea/Coffee Maker',
#  'Tea/Coffee Maker ',
#  'Telephone',
#  'Telephone ',
#  'Television',
#  'Tour Desk',
#  'Tour assistance',
#  'Transportation Service',
#  'Travel Assistance',
#  'Travel Desk',
#  'Travel desk',
#  'Travel:Free Parking',
#  'Travel:Parking',
#  'Travel:Parking,Airport Transfer',
#  'Travel:Travel Desk',
#  'Valet Parking',
#  'Wake up call',
#  'Wake up call service on request',
#  'Wardrobe',
#  'Wedding services',
#  'Wheelchair access',
#  'Wi Fi Internet',
#  'Wi-Fi',
#  'Wi-Fi Internet',
#  'Wi-Fi Internet access',
#  'Wi-Fi on Charge',
#  'WiFi',
#  'WiFi Internet',
#  'Wifi Enabled'}

# %%
data = pd.read_csv('/content/drive/MyDrive/Filtering_Data/content_filtered_data_restaurant.csv', encoding='utf-8')

# %%
cuisines =  set(','.join(data['Cuisines']).split(','))
cuisines
# Out:
# {' Bakery',
#  ' Bakery ',
#  ' Bakery - Dessert Parlour',
#  ' Beverages',
#  ' Beverages ',
#  ' Beverages - Dessert Parlour',
#  ' Beverages - Dessert Parlour ',
#  ' Beverages - Quick Bites',
#  ' Biryani',
#  ' Burger - Bakery',
#  ' Chinese',
#  ' Chinese - Casual Dining ',
#  ' Chinese - Quick Bites',
#  ' Desserts',
#  ' Desserts ',
#  ' Desserts - Bakery',
#  ' Desserts - Bakery ',
#  ' Desserts - Dessert Parlour',
#  ' Desserts - Dessert Parlour ',
#  ' Desserts - Food Court ',
#  ' Fast Food',
#  ' Fast Food ',
#  ' Fast Food - Café',
#  ' Fast Food - Dessert Parlour',
#  ' Fast Food - Dessert Parlour ',
#  ' Fast Food - Quick Bites',
#  ' Fast Food - Quick Bites ',
#  ' Frozen Yogurt - Café',
#  ' Ice Cream - Dessert Parlour',
#  ' Ice Cream - Dessert Parlour ',
#  ' Juices',
#  ' Juices - Quick Bites',
#  ' Kerala',
#  ' North Indian',
#  ' North Indian - Quick Bites',
#  ' North Indian - Quick Bites ',
#  ' Pizza',
#  ' Rolls',
#  ' Rolls - Quick Bites',
#  ' Rolls - Quick Bites ',
#  ' Sandwich',
#  ' Seafood',
#  ' Seafood - Casual Dining',
#  ' South Indian - Mess',
#  ' South Indian - Quick Bites',
#  ' South Indian - Sweet Shop',
#  ' Street Food',
#  ' Street Food - Quick Bites',
#  ' Tea',
#  ' Tea - Beverage Shop',
#  ' Wraps ',
#  'Andhra - Quick Bites',
#  'Arabian',
#  'Bakery',
#  'Beverages',
#  'Biryani',
#  'Biryani - Quick Bites',
#  'Cafe',
#  'Cafe - Café',
#  'Chettinad',
#  'Desserts',
#  'Desserts - Dessert Parlour',
#  'Fast Food',
#  'Fast Food ',
#  'Fast Food - Quick Bites',
#  'Fast Food - Quick Bites ',
#  'Ice Cream',
#  'Ice Cream - Dessert Parlour',
#  'Ice Cream - Dessert Parlour ',
#  'Mangalorean',
#  'Middle Eastern',
#  'Mithai',
#  'Mithai - Sweet Shop',
#  'Momos',
#  'North Indian',
#  'North Indian ',
#  'North Indian - ',
#  'North Indian - Quick Bites',
#  'Sandwich',
#  'Sandwich - Quick Bites',
#  'Sandwich - Quick Bites ',
#  'South Indian',
#  'South Indian ',
#  'South Indian - Casual Dining',
#  'South Indian - Casual Dining ',
#  'South Indian - Quick Bites',
#  'South Indian - Quick Bites ',
#  'Street Food',
#  'Tea'}

# %%
import csv
import random

# Define user preferences

locations = ["Koramangala", "Indiranagar", "JP Nagar", "Marathahalli", "HSR Layout", "Whitefield", "BTM Layout", "Malleshwaram"]



# Generate a user's preferences by randomly selecting values from the above lists
def generate_user_preferences():
    return {
        "categories": random.sample(categories, random.randint(1, len(categories))),
        "max_price": random.randint(100, 2000),
        "locations": random.sample(locations, random.randint(1, len(locations))),
        "min_rating": round(random.uniform(3.0, 5.0), 1),
        "cuisines": random.sample(cuisines, random.randint(0, len(cuisines))),
        "max_distance": round(random.uniform(0.5, 10.0), 1),  # in kilometers
        "facilities": random.sample(facilities, random.randint(0, len(facilities)))
    }

# Example usage: Generate preferences for 1000 users and save to CSV file
with open('user_preferences.csv', mode='w') as file:
    fieldnames = ['user_id', 'categories', 'max_price', 'locations', 'min_rating', 'cuisines', 'max_distance', 'facilities']
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    for i in range(1000):
        user_preferences = generate_user_preferences()
        writer.writerow({
            'user_id': i+1,
            'categories': ', '.join(user_preferences['categories']),
            'max_price': user_preferences['max_price'],
            'locations': ', '.join(user_preferences['locations']),
            'min_rating': user_preferences['min_rating'],
            'cuisines': ', '.join(user_preferences['cuisines']),
            'max_distance': user_preferences['max_distance'],
            'facilities': ', '.join(user_preferences['facilities'])
        })
# Out:
# <ipython-input-18-f7f6dc8b89a4>:13: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   "categories": random.sample(categories, random.randint(1, len(categories))),
# <ipython-input-18-f7f6dc8b89a4>:17: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   "cuisines": random.sample(cuisines, random.randint(0, len(cuisines))),
# <ipython-input-18-f7f6dc8b89a4>:19: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   "facilities": random.sample(facilities, random.randint(0, len(facilities)))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
# Load data
data = pd.read_csv('user_preferences.csv')
data.to_csv('/content/drive/MyDrive/Filtering_Data/user_preferences.csv', encoding='utf-8')
