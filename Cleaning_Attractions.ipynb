# %% [markdown]
# <a href="https://colab.research.google.com/github/ushifali/final-23/blob/master/Cleaning_Attractions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
     
# read the second CSV file
attraction_df = pd.read_csv('/content/drive/MyDrive/dATA/dataset_crawler-google-places_2023-03-21_14-01-20-553.csv',encoding='utf-8')

# %%
attraction_df
# Out:
#     additionalInfo/Accessibility/0/Assisted listening devices  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
#
#     additionalInfo/Accessibility/0/Wheelchair accessible elevator  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
#
#     additionalInfo/Accessibility/0/Wheelchair accessible entrance  \
# 0                                                  NaN
# 1                                                 True
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 302                                              False
# 303                                                NaN
# 304                                                NaN
# 305                                              False
# 306                                                NaN
#
#     additionalInfo/Accessibility/0/Wheelchair accessible parking lot  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
#
#     additionalInfo/Accessibility/0/Wheelchair accessible restroom  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
#
#     additionalInfo/Accessibility/1/Assistive hearing loop  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
#
#     additionalInfo/Accessibility/1/Wheelchair accessible entrance  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
#
#     additionalInfo/Accessibility/1/Wheelchair accessible parking lot  \
# 0                                                  NaN
# 1                                                 True
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 302                                              False
# 303                                                NaN
# 304                                                NaN
# 305                                              False
# 306                                                NaN
#
#     additionalInfo/Accessibility/1/Wheelchair accessible restroom  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
#
#     additionalInfo/Accessibility/2/Wheelchair accessible parking lot  ...  \
# 0                                                  NaN                ...
# 1                                                  NaN                ...
# 2                                                  NaN                ...
# 3                                                  NaN                ...
# 4                                                  NaN                ...
# ..                                                 ...                ...
# 302                                                NaN                ...
# 303                                                NaN                ...
# 304                                                NaN                ...
# 305                                                NaN                ...
# 306                                                NaN                ...
#
#     updatesFromCustomers/media/1/link updatesFromCustomers/media/1/postDate  \
# 0                                 NaN                                   NaN
# 1                                 NaN                                   NaN
# 2                                 NaN                                   NaN
# 3                                 NaN                                   NaN
# 4                                 NaN                                   NaN
# ..                                ...                                   ...
# 302                               NaN                                   NaN
# 303                               NaN                                   NaN
# 304                               NaN                                   NaN
# 305                               NaN                                   NaN
# 306                               NaN                                   NaN
#
#     updatesFromCustomers/postDate updatesFromCustomers/postedBy/name  \
# 0                             NaN                                NaN
# 1                      2 days ago                 Shiva godara Osian
# 2                             NaN                                NaN
# 3                             NaN                                NaN
# 4                             NaN                                NaN
# ..                            ...                                ...
# 302                   a month ago                        Amit Borade
# 303                           NaN                                NaN
# 304                           NaN                                NaN
# 305                           NaN                                NaN
# 306                    2 days ago                   Jyotiranjan Jena
#
#     updatesFromCustomers/postedBy/title  \
# 0                                   NaN
# 1                           Local Guide
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 302                         Local Guide
# 303                                 NaN
# 304                                 NaN
# 305                                 NaN
# 306                         Local Guide
#
#     updatesFromCustomers/postedBy/totalReviews  \
# 0                                          NaN
# 1                                          5.0
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 302                                       49.0
# 303                                        NaN
# 304                                        NaN
# 305                                        NaN
# 306                                       48.0
#
#                      updatesFromCustomers/postedBy/url  \
# 0                                                  NaN
# 1    https://www.google.com/maps/contrib/1147651257...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 302  https://www.google.com/maps/contrib/1057029303...
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306  https://www.google.com/maps/contrib/1013249107...
#
#                              updatesFromCustomers/text  \
# 0                                                  NaN
# 1                                  बहुत अच्छा पार्क है
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 302  On the occasion of Mahashivratri visited, crow...
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306                               It just a large pond
#
#                                                    url  \
# 0    https://www.google.com/maps/place/Uttarakhand/...
# 1    https://www.google.com/maps/place/Lalbagh+Bota...
# 2    https://www.google.com/maps/place/Sri+Sollapur...
# 3    https://www.google.com/maps/place/India+Flag/@...
# 4    https://www.google.com/maps/place/Lion+statue/...
# ..                                                 ...
# 302  https://www.google.com/maps/place/Sri+Someshwa...
# 303  https://www.google.com/maps/place/Kundalahalli...
# 304  https://www.google.com/maps/place/Akshay+holid...
# 305  https://www.google.com/maps/place/Kodandarama+...
# 306  https://www.google.com/maps/place/Panathur+Lak...
#
#                                             website
# 0                                               NaN
# 1    http://www.horticulture.kar.nic.in/lalbagh.htm
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 302                                             NaN
# 303                                             NaN
# 304                                             NaN
# 305                                             NaN
# 306                                             NaN
#
# [307 rows x 843 columns]

# %%
attraction_df = attraction_df.drop(attraction_df.filter(regex='updatesFromCustomers|^additionalInfo').columns, axis=1)
attraction_df
# Out:
#                                                address        categories/0  \
# 0    House number 72, 8th Main Rd, Vidyagiri Layout...  Tourist attraction
# 1          Mavalli, Bengaluru, Karnataka 560004, India  Tourist attraction
# 2    XGV3+RP6, Hegganahalli Main Rd, Sollapuradamma...  Tourist attraction
# 3    XJF2+6GQ, State Bank of India Rd, Shanthala Na...  Tourist attraction
# 4    38/1, Mohammedan Block, Basavanagudi, Bengalur...  Tourist attraction
# ..                                                 ...                 ...
# 302  Someshwara Temple Rd, Halasuru, Someshwarpura,...  Tourist attraction
# 303  C-33-1, Whitefield, Kundalahalli, Brookefield,...  Tourist attraction
# 304  WMFV+WVX, Doddakannelli - Kaadubeesanahalli Rd...  Tourist attraction
# 305  XH8V+8QG, Double Rd, Sampangi Rama Nagara, Ben...  Tourist attraction
# 306  WPJ4+QR, Kadubeesanahalli, Panathur, Bengaluru...  Tourist attraction
#
#          categories/1      categories/2 categories/3 categories/4  \
# 0                 NaN               NaN          NaN          NaN
# 1              Garden  Botanical garden          NaN          NaN
# 2        Hindu temple               NaN          NaN          NaN
# 3                 NaN               NaN          NaN          NaN
# 4                 NaN               NaN          NaN          NaN
# ..                ...               ...          ...          ...
# 302  Place of worship      Hindu temple          NaN          NaN
# 303               NaN               NaN          NaN          NaN
# 304               NaN               NaN          NaN          NaN
# 305      Hindu temple               NaN          NaN          NaN
# 306               NaN               NaN          NaN          NaN
#
#     categories/5 categories/6        categoryName                   cid  ...  \
# 0            NaN          NaN  Tourist attraction   3558145475226771319  ...
# 1            NaN          NaN    Botanical garden  10236976183492197922  ...
# 2            NaN          NaN        Hindu temple  15156762537273143701  ...
# 3            NaN          NaN  Tourist attraction  14175764870494430427  ...
# 4            NaN          NaN  Tourist attraction   3802464022739103937  ...
# ..           ...          ...                 ...                   ...  ...
# 302          NaN          NaN        Hindu temple   9765932494543294480  ...
# 303          NaN          NaN  Tourist attraction  16962141649502632457  ...
# 304          NaN          NaN  Tourist attraction   8191507186831251200  ...
# 305          NaN          NaN        Hindu temple   1331974317959972447  ...
# 306          NaN          NaN  Tourist attraction   1707528372804880983  ...
#
#                                          searchPageUrl  searchString  \
# 0    https://www.google.com/maps/search/attraction/...    attraction
# 1    https://www.google.com/maps/search/attraction/...    attraction
# 2    https://www.google.com/maps/search/attraction/...    attraction
# 3    https://www.google.com/maps/search/attraction/...    attraction
# 4    https://www.google.com/maps/search/attraction/...    attraction
# ..                                                 ...           ...
# 302  https://www.google.com/maps/search/attraction/...    attraction
# 303  https://www.google.com/maps/search/attraction/...    attraction
# 304  https://www.google.com/maps/search/attraction/...    attraction
# 305  https://www.google.com/maps/search/attraction/...    attraction
# 306  https://www.google.com/maps/search/attraction/...    attraction
#
#          state                                          street  \
# 0    Karnataka                    House number 72, 8th Main Rd
# 1    Karnataka                                             NaN
# 2    Karnataka                  XGV3+RP6, Hegganahalli Main Rd
# 3    Karnataka                XJF2+6GQ, State Bank of India Rd
# 4    Karnataka                                            38/1
# ..         ...                                             ...
# 302  Karnataka                            Someshwara Temple Rd
# 303  Karnataka                                          C-33-1
# 304  Karnataka  WMFV+WVX, Doddakannelli - Kaadubeesanahalli Rd
# 305  Karnataka                             XH8V+8QG, Double Rd
# 306  Karnataka                                         WPJ4+QR
#
#                       subTitle temporarilyClosed  \
# 0                    ಉತ್ತರಖಂಡ್             False
# 1       ಕೆಂಪು ತೋಟ ಸಸ್ಯೋದ್ಯಾನ             False
# 2    ಶ್ರೀ ಸೊಲ್ಲಾಪುರದಮ್ಮ ಟೆಂಪಲ್             False
# 3                          NaN             False
# 4                          NaN             False
# ..                         ...               ...
# 302                        NaN             False
# 303                        NaN             False
# 304                        NaN             False
# 305     ಶ್ರೀ ಕೋದಂಡರಾಮ ದೇವಸ್ಥಾನ             False
# 306                        NaN             False
#
#                                  title  totalScore  \
# 0                          Uttarakhand         NaN
# 1             Lalbagh Botanical Garden         4.4
# 2            Sri Sollapuradamma Temple         4.6
# 3                           India Flag         NaN
# 4                          Lion statue         4.8
# ..                                 ...         ...
# 302        Sri Someshwara Swami Temple         4.7
# 303                  Kundalahalli Lake         3.9
# 304  Akshay holidays tours and travels         5.0
# 305             Kodandarama Devasthana         4.5
# 306               Panathur Lake Island         4.1
#
#                                                    url  \
# 0    https://www.google.com/maps/place/Uttarakhand/...
# 1    https://www.google.com/maps/place/Lalbagh+Bota...
# 2    https://www.google.com/maps/place/Sri+Sollapur...
# 3    https://www.google.com/maps/place/India+Flag/@...
# 4    https://www.google.com/maps/place/Lion+statue/...
# ..                                                 ...
# 302  https://www.google.com/maps/place/Sri+Someshwa...
# 303  https://www.google.com/maps/place/Kundalahalli...
# 304  https://www.google.com/maps/place/Akshay+holid...
# 305  https://www.google.com/maps/place/Kodandarama+...
# 306  https://www.google.com/maps/place/Panathur+Lak...
#
#                                             website
# 0                                               NaN
# 1    http://www.horticulture.kar.nic.in/lalbagh.htm
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 302                                             NaN
# 303                                             NaN
# 304                                             NaN
# 305                                             NaN
# 306                                             NaN
#
# [307 rows x 792 columns]

# %%
# To concatenate values from the categories/0, categories/1, categories/2, categories/3, categories/4, categories/5,
#  and categories/6 columns into a single categories column while ignoring the NaN values,
#  you can use the apply() method in pandas along with a lambda function. Here's the code to do so: 
attraction_df['categories'] = attraction_df.apply(lambda x: ', '.join([str(x[f'categories/{i}']) \
                                                                       for i in range(7) if pd.notnull(x[f'categories/{i}'])]), axis=1)

# %%
attraction_df.drop(['categories/0', 'categories/1', 'categories/2', 'categories/3', 'categories/4', 'categories/5', 'categories/6'], axis=1, inplace=True)

# %%
print(attraction_df.columns)
# Out:
# Index(['address', 'categoryName', 'cid', 'city', 'claimThisBusiness',
#        'countryCode', 'description', 'imageUrls/0', 'imageUrls/1',
#        'imagesCount',
#        ...
#        'searchString', 'state', 'street', 'subTitle', 'temporarilyClosed',
#        'title', 'totalScore', 'url', 'website', 'categories'],
#       dtype='object', length=786)

# %%
columns_to_drop = ['cid', 'claimThisBusiness','countryCode','imagesCount','temporarilyClosed','subTitle']
attraction_df.drop(columns_to_drop , axis=1, inplace=True)
print(attraction_df.columns)
# Out:
# Index(['address', 'categoryName', 'city', 'description', 'imageUrls/0',
#        'imageUrls/1', 'isAdvertisement', 'locatedIn', 'location/lat',
#        'location/lng',
#        ...
#        'searchPageLoadedUrl', 'searchPageUrl', 'searchString', 'state',
#        'street', 'title', 'totalScore', 'url', 'website', 'categories'],
#       dtype='object', length=780)

# %%
attraction_df = attraction_df.drop(attraction_df.filter(regex='^peopleAlsoSearch|^placesTags|^popularTimesHistogram|^searchPageLoadedUrl|^scrapedAt|^searchString').columns, axis=1)
attraction_df

# %%
attraction_df = attraction_df.drop(attraction_df.filter(regex='^isAdvertisement|^openingHours|^menu|^orderBy|^permanentlyClosed|^questionsAndAnswers').columns, axis=1)

# %%
columns_to_drop = ['neighborhood', 'placeId','plusCode','popularTimesLivePercent','popularTimesLiveText','postalCode','searchPageUrl']
attraction_df.drop(columns_to_drop , axis=1, inplace=True)

# %%
columns_to_drop = ['website', 'url','locatedIn','categoryName','phone']
attraction_df.drop(columns_to_drop , axis=1, inplace=True)

# %%
columns_to_drop = [	'rank',	'reviewsCount'	]
attraction_df.drop(columns_to_drop , axis=1, inplace=True)

# %%
attraction_df = attraction_df.drop(attraction_df.filter(regex='^reviews/').columns, axis=1)

# %%
attraction_df = attraction_df.drop(attraction_df.filter(regex='^reviewsDistribution|^reviewsTags').columns, axis=1)

# %%
attraction_df = attraction_df.rename(columns={'location/lat': 'latitude', 'location/lng': 'longitude'})

# %%
#To concatenate the values of the imageUrls/0 and imageUrls/1 columns into a single column named image_url, 
# you can use the apply() method along with a lambda function in pandas.
attraction_df['image_url'] = attraction_df[['imageUrls/0', 'imageUrls/1']].apply(lambda x: ','.join(x.dropna().astype(str)), axis=1)

# %%
attraction_df = attraction_df.drop(['imageUrls/0', 'imageUrls/1'], axis=1)

# %%
for col in attraction_df.columns:
    print(col)
# Out:
# address
# city
# description
# latitude
# longitude
# price
# state
# street
# title
# totalScore
# categories
# image_url

# %%
attraction_df.to_csv('/content/drive/MyDrive/Cleaned_Data/combined/attractions_data.csv')
