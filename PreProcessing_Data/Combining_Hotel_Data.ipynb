# %% [markdown]
# <a href="https://colab.research.google.com/github/ushifali/final-23/blob/main/Combining_hotel_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# read the first CSV file
df1 = pd.read_csv('/content/drive/MyDrive/Cleaned_Data/CLear_Trip_Travel.csv')
df2 = pd.read_csv('/content/drive/MyDrive/Cleaned_Data/goibibo.csv')

# %%
df1.head()
# Out:
#                                              address  \
# 0                                9th Mile, Kalimpong
# 1                 New Kalimati Road, Kasidih, Sakchi
# 2  Opposite Nagarpalika, Near Pushkarna Bera, Pos...
# 3      11-3-11 Veterinary Hospital road,Ramarao peta
# 4                   Near Fort First Gate, Dhibbapara
#
#                          area        city  \
# 0       Rishi Road-Highway 12   Kalimpong
# 1                         NaN  Jamshedpur
# 2                         NaN   Jaisalmer
# 3                 Cinema Road    Kakinada
# 4  Near Jaisalmer Golden Fort   Jaisalmer
#
#                                    hotel_description  \
# 0  Hotel Jiwan Jyoti, Kalimpong is an ultimate st...
# 1  Retire to the beautiful rooms of OYO Premium K...
# 2  OYO Rooms Bera Road in Jaisalmer has a royal c...
# 3  Situated in quite part of the city yet close t...
# 4  Hotel Gorakh Haveli, Jaisalmer, with hospitali...
#
# ...

# %%
df2.head()
# Out:
#                                              address            area     city  \
# 0  15th Mile, N.H.21,Manali, District Kullu,Himac...          Others   Manali
# 1  A-585, Sushant Lok-1 ,Near Iffco Chowk Metro S...     Sushant Lok  Gurgaon
# 2  Cobra Vaddo,Calungate Baga Road, Bardez, Calan...  Calangute Area      Goa
# 3                                              Simsa   Village Simsa   Manali
# 4         8180 Street No.-6,Arakashan Road,Paharganj       Paharganj    Delhi
#
#    rating                                  hotel_description  \
# 0     8.5  The standard check-in time is 12:00 PM and the...
# 1     8.7  The standard check-in time is 12:00 PM and the...
# 2     5.0  The standard check-in time is 12:00 PM and the...
# 3    10.0  The standard check-in time is 12:00 PM and the...
# 4     6.3  The standard check-in time is 12:00 PM and the...
#
#                                     hotel_facilities  hotel_star_rating  \
# ...

# %%
# combine the two dataframes
combined_df = pd.concat([df1, df2])

# save the combined dataframe to a new CSV file
combined_df.to_csv('/content/drive/MyDrive/Cleaned_Data/combined/final_hotel_dataset.csv', index=False)

# %%
df3 = pd.read_csv('/content/drive/MyDrive/Cleaned_Data/combined/final_hotel_dataset.csv')
df4 = pd.read_csv('/content/drive/MyDrive/Cleaned_Data/MakeMyTrip.csv')

combined_df = pd.concat([df3, df4])

# save the combined dataframe to a new CSV file
combined_df.to_csv('/content/drive/MyDrive/Cleaned_Data/combined/final_hotel_dataset.csv', index=True)
